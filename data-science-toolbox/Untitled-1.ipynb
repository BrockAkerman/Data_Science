# %% [markdown]
# TCREI
#
# TASK, CONTEXT, REERENCES, EVALUATE, ITERATE
# THOUGHTFULLYG CREATE REALLY EXCELLENT INPUTS

# %%
pip install llama-index-llms-ollama
# Out:
# Requirement already satisfied: llama-index-llms-ollama in a:\Programs\Python\Lib\site-packages (0.10.1)
# Requirement already satisfied: llama-index-core<0.15,>=0.14.5 in a:\Programs\Python\Lib\site-packages (from llama-index-llms-ollama) (0.14.19)
# Requirement already satisfied: ollama>=0.5.3 in a:\Programs\Python\Lib\site-packages (from llama-index-llms-ollama) (0.6.1)
# Requirement already satisfied: aiohttp<4,>=3.8.6 in a:\Programs\Python\Lib\site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (3.13.3)
# Requirement already satisfied: aiosqlite in a:\Programs\Python\Lib\site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (0.22.1)
# Requirement already satisfied: banks<3,>=2.3.0 in a:\Programs\Python\Lib\site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (2.4.1)
# Requirement already satisfied: dataclasses-json in a:\Programs\Python\Lib\site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in a:\Programs\Python\Lib\site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (1.3.1)
# Requirement already satisfied: dirtyjson<2,>=1.0.8 in a:\Programs\Python\Lib\site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (1.0.8)
# Requirement already satisfied: filetype<2,>=1.2.0 in a:\Programs\Python\Lib\site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in a:\Programs\Python\Lib\site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (2026.2.0)
# Requirement already satisfied: httpx in a:\Programs\Python\Lib\site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (0.28.1)
# Requirement already satisfied: llama-index-workflows!=2.9.0,<3,>=2 in a:\Programs\Python\Lib\site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (2.17.1)
# Requirement already satisfied: nest-asyncio<2,>=1.5.8 in a:\Programs\Python\Lib\site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in a:\Programs\Python\Lib\site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (3.6.1)
# Requirement already satisfied: nltk>3.8.1 in a:\Programs\Python\Lib\site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (3.9.4)
# Requirement already satisfied: numpy in a:\Programs\Python\Lib\site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (2.4.2)
# Requirement already satisfied: pillow>=9.0.0 in a:\Programs\Python\Lib\site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (12.1.1)
# Requirement already satisfied: platformdirs in a:\Programs\Python\Lib\site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (4.9.2)
# Requirement already satisfied: pydantic>=2.8.0 in a:\Programs\Python\Lib\site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (2.12.5)
# Requirement already satisfied: pyyaml>=6.0.1 in a:\Programs\Python\Lib\site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (6.0.3)
# Requirement already satisfied: requests>=2.31.0 in a:\Programs\Python\Lib\site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (2.32.5)
# Requirement already satisfied: setuptools>=80.9.0 in a:\Programs\Python\Lib\site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (81.0.0)
# Requirement already satisfied: sqlalchemy>=1.4.49 in a:\Programs\Python\Lib\site-packages (from sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (2.0.48)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in a:\Programs\Python\Lib\site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (9.1.4)
# Requirement already satisfied: tiktoken>=0.7.0 in a:\Programs\Python\Lib\site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (0.12.0)
# Requirement already satisfied: tinytag>=2.2.0 in a:\Programs\Python\Lib\site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (2.2.1)
# Requirement already satisfied: tqdm<5,>=4.66.1 in a:\Programs\Python\Lib\site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (4.67.3)
# Requirement already satisfied: typing-extensions>=4.5.0 in a:\Programs\Python\Lib\site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (4.15.0)
# Requirement already satisfied: typing-inspect>=0.8.0 in a:\Programs\Python\Lib\site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (0.9.0)
# Requirement already satisfied: wrapt in a:\Programs\Python\Lib\site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (2.1.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in a:\Programs\Python\Lib\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in a:\Programs\Python\Lib\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in a:\Programs\Python\Lib\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in a:\Programs\Python\Lib\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in a:\Programs\Python\Lib\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in a:\Programs\Python\Lib\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in a:\Programs\Python\Lib\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (1.23.0)
# Requirement already satisfied: griffe in a:\Programs\Python\Lib\site-packages (from banks<3,>=2.3.0->llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (2.0.1)
# Requirement already satisfied: jinja2 in a:\Programs\Python\Lib\site-packages (from banks<3,>=2.3.0->llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (3.1.6)
# Requirement already satisfied: llama-index-instrumentation>=0.4.3 in a:\Programs\Python\Lib\site-packages (from llama-index-workflows!=2.9.0,<3,>=2->llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (0.5.0)
# Requirement already satisfied: colorama in a:\Programs\Python\Lib\site-packages (from tqdm<5,>=4.66.1->llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (0.4.6)
# Requirement already satisfied: idna>=2.0 in a:\Programs\Python\Lib\site-packages (from yarl<2.0,>=1.17.0->aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (3.11)
# Requirement already satisfied: click in a:\Programs\Python\Lib\site-packages (from nltk>3.8.1->llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (8.3.1)
# Requirement already satisfied: joblib in a:\Programs\Python\Lib\site-packages (from nltk>3.8.1->llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in a:\Programs\Python\Lib\site-packages (from nltk>3.8.1->llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (2026.2.28)
# Requirement already satisfied: anyio in a:\Programs\Python\Lib\site-packages (from httpx->llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (4.12.1)
# Requirement already satisfied: certifi in a:\Programs\Python\Lib\site-packages (from httpx->llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in a:\Programs\Python\Lib\site-packages (from httpx->llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (1.0.9)
# Requirement already satisfied: h11>=0.16 in a:\Programs\Python\Lib\site-packages (from httpcore==1.*->httpx->llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in a:\Programs\Python\Lib\site-packages (from pydantic>=2.8.0->llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in a:\Programs\Python\Lib\site-packages (from pydantic>=2.8.0->llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in a:\Programs\Python\Lib\site-packages (from pydantic>=2.8.0->llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in a:\Programs\Python\Lib\site-packages (from requests>=2.31.0->llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in a:\Programs\Python\Lib\site-packages (from requests>=2.31.0->llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (2.6.3)
# Requirement already satisfied: greenlet>=1 in a:\Programs\Python\Lib\site-packages (from sqlalchemy>=1.4.49->sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (3.3.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in a:\Programs\Python\Lib\site-packages (from typing-inspect>=0.8.0->llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (1.1.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in a:\Programs\Python\Lib\site-packages (from dataclasses-json->llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (3.26.2)
# Requirement already satisfied: packaging>=17.0 in a:\Programs\Python\Lib\site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (26.0)
# Requirement already satisfied: griffecli==2.0.1 in a:\Programs\Python\Lib\site-packages (from griffe->banks<3,>=2.3.0->llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (2.0.1)
# Requirement already satisfied: griffelib==2.0.1 in a:\Programs\Python\Lib\site-packages (from griffe->banks<3,>=2.3.0->llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (2.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in a:\Programs\Python\Lib\site-packages (from jinja2->banks<3,>=2.3.0->llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (3.0.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install llama-index-embeddings-huggingface
# Out:
# Collecting llama-index-embeddings-huggingface
#   Using cached llama_index_embeddings_huggingface-0.7.0-py3-none-any.whl.metadata (459 bytes)
# Collecting huggingface-hub>=0.19.0 (from huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface)
#   Using cached huggingface_hub-1.8.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: llama-index-core<0.15,>=0.13.0 in a:\Programs\Python\Lib\site-packages (from llama-index-embeddings-huggingface) (0.14.19)
# Collecting sentence-transformers>=2.6.1 (from llama-index-embeddings-huggingface)
#   Using cached sentence_transformers-5.3.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: aiohttp<4,>=3.8.6 in a:\Programs\Python\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (3.13.3)
# Requirement already satisfied: aiosqlite in a:\Programs\Python\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (0.22.1)
# Requirement already satisfied: banks<3,>=2.3.0 in a:\Programs\Python\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (2.4.1)
# Requirement already satisfied: dataclasses-json in a:\Programs\Python\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in a:\Programs\Python\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (1.3.1)
# Requirement already satisfied: dirtyjson<2,>=1.0.8 in a:\Programs\Python\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (1.0.8)
# Requirement already satisfied: filetype<2,>=1.2.0 in a:\Programs\Python\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in a:\Programs\Python\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (2026.2.0)
# Requirement already satisfied: httpx in a:\Programs\Python\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (0.28.1)
# Requirement already satisfied: llama-index-workflows!=2.9.0,<3,>=2 in a:\Programs\Python\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (2.17.1)
# Requirement already satisfied: nest-asyncio<2,>=1.5.8 in a:\Programs\Python\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in a:\Programs\Python\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (3.6.1)
# Requirement already satisfied: nltk>3.8.1 in a:\Programs\Python\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (3.9.4)
# Requirement already satisfied: numpy in a:\Programs\Python\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (2.4.2)
# Requirement already satisfied: pillow>=9.0.0 in a:\Programs\Python\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (12.1.1)
# Requirement already satisfied: platformdirs in a:\Programs\Python\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (4.9.2)
# Requirement already satisfied: pydantic>=2.8.0 in a:\Programs\Python\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (2.12.5)
# Requirement already satisfied: pyyaml>=6.0.1 in a:\Programs\Python\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (6.0.3)
# Requirement already satisfied: requests>=2.31.0 in a:\Programs\Python\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (2.32.5)
# Requirement already satisfied: setuptools>=80.9.0 in a:\Programs\Python\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (82.0.0)
# Requirement already satisfied: sqlalchemy>=1.4.49 in a:\Programs\Python\Lib\site-packages (from sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (2.0.48)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in a:\Programs\Python\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (9.1.4)
# Requirement already satisfied: tiktoken>=0.7.0 in a:\Programs\Python\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (0.12.0)
# Requirement already satisfied: tinytag>=2.2.0 in a:\Programs\Python\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (2.2.1)
# Requirement already satisfied: tqdm<5,>=4.66.1 in a:\Programs\Python\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (4.67.3)
# Requirement already satisfied: typing-extensions>=4.5.0 in a:\Programs\Python\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (4.15.0)
# Requirement already satisfied: typing-inspect>=0.8.0 in a:\Programs\Python\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (0.9.0)
# Requirement already satisfied: wrapt in a:\Programs\Python\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (2.1.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in a:\Programs\Python\Lib\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in a:\Programs\Python\Lib\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in a:\Programs\Python\Lib\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in a:\Programs\Python\Lib\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in a:\Programs\Python\Lib\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in a:\Programs\Python\Lib\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in a:\Programs\Python\Lib\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (1.23.0)
# Requirement already satisfied: griffe in a:\Programs\Python\Lib\site-packages (from banks<3,>=2.3.0->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (2.0.1)
# Requirement already satisfied: jinja2 in a:\Programs\Python\Lib\site-packages (from banks<3,>=2.3.0->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (3.1.6)
# Requirement already satisfied: llama-index-instrumentation>=0.4.3 in a:\Programs\Python\Lib\site-packages (from llama-index-workflows!=2.9.0,<3,>=2->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (0.5.0)
# Requirement already satisfied: colorama in a:\Programs\Python\Lib\site-packages (from tqdm<5,>=4.66.1->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (0.4.6)
# Requirement already satisfied: idna>=2.0 in a:\Programs\Python\Lib\site-packages (from yarl<2.0,>=1.17.0->aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (3.11)
# Collecting filelock>=3.10.0 (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface)
#   Using cached filelock-3.25.2-py3-none-any.whl.metadata (2.0 kB)
# Collecting hf-xet<2.0.0,>=1.4.2 (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface)
#   Using cached hf_xet-1.4.2-cp37-abi3-win_amd64.whl.metadata (4.9 kB)
# Requirement already satisfied: packaging>=20.9 in a:\Programs\Python\Lib\site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (26.0)
# Collecting typer (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface)
#   Using cached typer-0.24.1-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: anyio in a:\Programs\Python\Lib\site-packages (from httpx->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (4.12.1)
# Requirement already satisfied: certifi in a:\Programs\Python\Lib\site-packages (from httpx->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in a:\Programs\Python\Lib\site-packages (from httpx->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (1.0.9)
# Requirement already satisfied: h11>=0.16 in a:\Programs\Python\Lib\site-packages (from httpcore==1.*->httpx->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (0.16.0)
# Requirement already satisfied: click in a:\Programs\Python\Lib\site-packages (from nltk>3.8.1->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (8.3.1)
# Requirement already satisfied: joblib in a:\Programs\Python\Lib\site-packages (from nltk>3.8.1->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in a:\Programs\Python\Lib\site-packages (from nltk>3.8.1->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (2026.2.28)
# Requirement already satisfied: annotated-types>=0.6.0 in a:\Programs\Python\Lib\site-packages (from pydantic>=2.8.0->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in a:\Programs\Python\Lib\site-packages (from pydantic>=2.8.0->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in a:\Programs\Python\Lib\site-packages (from pydantic>=2.8.0->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in a:\Programs\Python\Lib\site-packages (from requests>=2.31.0->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in a:\Programs\Python\Lib\site-packages (from requests>=2.31.0->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (2.6.3)
# Collecting transformers<6.0.0,>=4.41.0 (from sentence-transformers>=2.6.1->llama-index-embeddings-huggingface)
#   Using cached transformers-5.3.0-py3-none-any.whl.metadata (32 kB)
# Collecting torch>=1.11.0 (from sentence-transformers>=2.6.1->llama-index-embeddings-huggingface)
#   Downloading torch-2.11.0-cp313-cp313-win_amd64.whl.metadata (29 kB)
# Requirement already satisfied: scikit-learn in a:\Programs\Python\Lib\site-packages (from sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (1.8.0)
# Requirement already satisfied: scipy in a:\Programs\Python\Lib\site-packages (from sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (1.17.1)
# Collecting tokenizers<=0.23.0,>=0.22.0 (from transformers<6.0.0,>=4.41.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface)
#   Using cached tokenizers-0.22.2-cp39-abi3-win_amd64.whl.metadata (7.4 kB)
# Collecting safetensors>=0.4.3 (from transformers<6.0.0,>=4.41.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface)
#   Using cached safetensors-0.7.0-cp38-abi3-win_amd64.whl.metadata (4.2 kB)
# Requirement already satisfied: greenlet>=1 in a:\Programs\Python\Lib\site-packages (from sqlalchemy>=1.4.49->sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (3.3.2)
# Collecting setuptools>=80.9.0 (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface)
#   Using cached setuptools-81.0.0-py3-none-any.whl.metadata (6.6 kB)
# Collecting sympy>=1.13.3 (from torch>=1.11.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface)
#   Using cached sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface)
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: mypy-extensions>=0.3.0 in a:\Programs\Python\Lib\site-packages (from typing-inspect>=0.8.0->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (1.1.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in a:\Programs\Python\Lib\site-packages (from dataclasses-json->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (3.26.2)
# Requirement already satisfied: griffecli==2.0.1 in a:\Programs\Python\Lib\site-packages (from griffe->banks<3,>=2.3.0->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (2.0.1)
# Requirement already satisfied: griffelib==2.0.1 in a:\Programs\Python\Lib\site-packages (from griffe->banks<3,>=2.3.0->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (2.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in a:\Programs\Python\Lib\site-packages (from jinja2->banks<3,>=2.3.0->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (3.0.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in a:\Programs\Python\Lib\site-packages (from scikit-learn->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (3.6.0)
# Collecting shellingham>=1.3.0 (from typer->huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface)
#   Using cached shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting rich>=12.3.0 (from typer->huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface)
#   Using cached rich-14.3.3-py3-none-any.whl.metadata (18 kB)
# Collecting annotated-doc>=0.0.2 (from typer->huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface)
#   Using cached annotated_doc-0.0.4-py3-none-any.whl.metadata (6.6 kB)
# Collecting markdown-it-py>=2.2.0 (from rich>=12.3.0->typer->huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface)
#   Using cached markdown_it_py-4.0.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in a:\Programs\Python\Lib\site-packages (from rich>=12.3.0->typer->huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (2.19.2)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface)
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Using cached llama_index_embeddings_huggingface-0.7.0-py3-none-any.whl (8.9 kB)
# Using cached huggingface_hub-1.8.0-py3-none-any.whl (625 kB)
# Using cached hf_xet-1.4.2-cp37-abi3-win_amd64.whl (3.7 MB)
# Using cached filelock-3.25.2-py3-none-any.whl (26 kB)
# Using cached sentence_transformers-5.3.0-py3-none-any.whl (512 kB)
# Using cached transformers-5.3.0-py3-none-any.whl (10.7 MB)
# Using cached tokenizers-0.22.2-cp39-abi3-win_amd64.whl (2.7 MB)
# Using cached safetensors-0.7.0-cp38-abi3-win_amd64.whl (341 kB)
# Downloading torch-2.11.0-cp313-cp313-win_amd64.whl (114.6 MB)
#    ---------------------------------------- 0.0/114.6 MB ? eta -:--:--
#    - -------------------------------------- 2.9/114.6 MB 19.5 MB/s eta 0:00:06
#    ------- -------------------------------- 20.2/114.6 MB 56.2 MB/s eta 0:00:02
#    --------------- ------------------------ 44.8/114.6 MB 79.2 MB/s eta 0:00:01
#    ------------------------ --------------- 69.5/114.6 MB 89.8 MB/s eta 0:00:01
#    --------------------------------- ------ 95.2/114.6 MB 96.1 MB/s eta 0:00:01
#    --------------------------------------  114.3/114.6 MB 99.3 MB/s eta 0:00:01
#    --------------------------------------  114.3/114.6 MB 99.3 MB/s eta 0:00:01
#    ---------------------------------------- 114.6/114.6 MB 76.1 MB/s  0:00:01
# Using cached setuptools-81.0.0-py3-none-any.whl (1.1 MB)
# Using cached sympy-1.14.0-py3-none-any.whl (6.3 MB)
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Using cached typer-0.24.1-py3-none-any.whl (56 kB)
# Using cached annotated_doc-0.0.4-py3-none-any.whl (5.3 kB)
# Using cached rich-14.3.3-py3-none-any.whl (310 kB)
# Using cached markdown_it_py-4.0.0-py3-none-any.whl (87 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Using cached shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Installing collected packages: mpmath, sympy, shellingham, setuptools, safetensors, mdurl, hf-xet, filelock, annotated-doc, torch, markdown-it-py, rich, typer, huggingface-hub, tokenizers, transformers, sentence-transformers, llama-index-embeddings-huggingface
#
#    ----------------------------------------  0/18 [mpmath]
#    ----------------------------------------  0/18 [mpmath]
#    ----------------------------------------  0/18 [mpmath]
#    ----------------------------------------  0/18 [mpmath]
#    ----------------------------------------  0/18 [mpmath]
#    ----------------------------------------  0/18 [mpmath]
#    ----------------------------------------  0/18 [mpmath]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    -- -------------------------------------  1/18 [sympy]
#    ---- -----------------------------------  2/18 [shellingham]
#   Attempting uninstall: setuptools
#    ---- -----------------------------------  2/18 [shellingham]
#     Found existing installation: setuptools 82.0.0
#    ---- -----------------------------------  2/18 [shellingham]
#    ------ ---------------------------------  3/18 [setuptools]
#     Uninstalling setuptools-82.0.0:
#    ------ ---------------------------------  3/18 [setuptools]
#    ------ ---------------------------------  3/18 [setuptools]
#    ------ ---------------------------------  3/18 [setuptools]
#    ------ ---------------------------------  3/18 [setuptools]
#    ------ ---------------------------------  3/18 [setuptools]
#       Successfully uninstalled setuptools-82.0.0
#    ------ ---------------------------------  3/18 [setuptools]
#    ------ ---------------------------------  3/18 [setuptools]
#    ------ ---------------------------------  3/18 [setuptools]
#    ------ ---------------------------------  3/18 [setuptools]
#    ------ ---------------------------------  3/18 [setuptools]
#    ------ ---------------------------------  3/18 [setuptools]
#    ------ ---------------------------------  3/18 [setuptools]
#    ------ ---------------------------------  3/18 [setuptools]
#    ------ ---------------------------------  3/18 [setuptools]
#    ------ ---------------------------------  3/18 [setuptools]
#    ------ ---------------------------------  3/18 [setuptools]
#    ------ ---------------------------------  3/18 [setuptools]
#    ------ ---------------------------------  3/18 [setuptools]
#    ------ ---------------------------------  3/18 [setuptools]
#    ------ ---------------------------------  3/18 [setuptools]
#    ------ ---------------------------------  3/18 [setuptools]
#    ------ ---------------------------------  3/18 [setuptools]
#    ------ ---------------------------------  3/18 [setuptools]
#    ------ ---------------------------------  3/18 [setuptools]
#    ------ ---------------------------------  3/18 [setuptools]
#    ------ ---------------------------------  3/18 [setuptools]
#    ------ ---------------------------------  3/18 [setuptools]
#    ------ ---------------------------------  3/18 [setuptools]
#    ------ ---------------------------------  3/18 [setuptools]
#    -------- -------------------------------  4/18 [safetensors]
#    ------------- --------------------------  6/18 [hf-xet]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    -------------------- -------------------  9/18 [torch]
#    ---------------------- ----------------- 10/18 [markdown-it-py]
#    ---------------------- ----------------- 10/18 [markdown-it-py]
#    ---------------------- ----------------- 10/18 [markdown-it-py]
#    ---------------------- ----------------- 10/18 [markdown-it-py]
#    ------------------------ --------------- 11/18 [rich]
#    ------------------------ --------------- 11/18 [rich]
#    ------------------------ --------------- 11/18 [rich]
#    ------------------------ --------------- 11/18 [rich]
#    ------------------------ --------------- 11/18 [rich]
#    ------------------------ --------------- 11/18 [rich]
#    ------------------------ --------------- 11/18 [rich]
#    -------------------------- ------------- 12/18 [typer]
#    ---------------------------- ----------- 13/18 [huggingface-hub]
#    ---------------------------- ----------- 13/18 [huggingface-hub]
#    ---------------------------- ----------- 13/18 [huggingface-hub]
#    ---------------------------- ----------- 13/18 [huggingface-hub]
#    ---------------------------- ----------- 13/18 [huggingface-hub]
#    ---------------------------- ----------- 13/18 [huggingface-hub]
#    ---------------------------- ----------- 13/18 [huggingface-hub]
#    ---------------------------- ----------- 13/18 [huggingface-hub]
#    ---------------------------- ----------- 13/18 [huggingface-hub]
#    ---------------------------- ----------- 13/18 [huggingface-hub]
#    ---------------------------- ----------- 13/18 [huggingface-hub]
#    ---------------------------- ----------- 13/18 [huggingface-hub]
#    ---------------------------- ----------- 13/18 [huggingface-hub]
#    ------------------------------- -------- 14/18 [tokenizers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    --------------------------------- ------ 15/18 [transformers]
#    ----------------------------------- ---- 16/18 [sentence-transformers]
#    ----------------------------------- ---- 16/18 [sentence-transformers]
#    ----------------------------------- ---- 16/18 [sentence-transformers]
#    ----------------------------------- ---- 16/18 [sentence-transformers]
#    ----------------------------------- ---- 16/18 [sentence-transformers]
#    ----------------------------------- ---- 16/18 [sentence-transformers]
#    ----------------------------------- ---- 16/18 [sentence-transformers]
#    ----------------------------------- ---- 16/18 [sentence-transformers]
#    ----------------------------------- ---- 16/18 [sentence-transformers]
#    ----------------------------------- ---- 16/18 [sentence-transformers]
#    ----------------------------------- ---- 16/18 [sentence-transformers]
#    ----------------------------------- ---- 16/18 [sentence-transformers]
#    --------------------------------- 18/18 [llama-index-embeddings-huggingface]
#
# Successfully installed annotated-doc-0.0.4 filelock-3.25.2 hf-xet-1.4.2 huggingface-hub-1.8.0 llama-index-embeddings-huggingface-0.7.0 markdown-it-py-4.0.0 mdurl-0.1.2 mpmath-1.3.0 rich-14.3.3 safetensors-0.7.0 sentence-transformers-5.3.0 setuptools-81.0.0 shellingham-1.5.4 sympy-1.14.0 tokenizers-0.22.2 torch-2.11.0 transformers-5.3.0 typer-0.24.1
# Note: you may need to restart the kernel to use updated packages.
# WARNING: huggingface-hub 1.8.0 does not provide the extra 'inference'

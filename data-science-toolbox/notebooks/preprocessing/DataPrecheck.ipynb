# %% [markdown]
# Check data types and structure.
#
# Check missing values.
#
# Check duplicates.
#
# Check distributions of all features.
#
# Check outliers.
#
# Check relationships between features.
#
# Check target distribution (if supervised).
#
# Check time ordering (if time-based).
#
# Document insights and data issues.

# %%
pip install pandas-profiling
# Out:
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#    ---------------------------------------- 0.0/4.7 MB ? eta -:--:--
#    ---------------------------------------- 4.7/4.7 MB 70.9 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/676.2 kB ? eta -:--:--
#    --------------------------------------- 676.2/676.2 kB 27.6 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 2.1/2.1 MB 56.4 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/4.2 MB ? eta -:--:--
#    ---------------------------------------- 4.2/4.2 MB 63.7 MB/s eta 0:00:00
# ...

# %% [markdown]
# ##### Understand Data Context

# %% [markdown]
# ##### Load and Inspect

# %% [markdown]
# ##### Data Quality Checks

# %% [markdown]
# ##### Univariate Analysis

# %% [markdown]
# ##### Outlier Detection

# %% [markdown]
# ##### Feature Relationships

# %%
# HEAT MAP Correlation Matrix
corr = data.select_dtypes(include=np.number).corr()
plt.figure(figsize=(10,8))
sns.heatmap(corr, annot=True, cmap='coolwarm', center=0)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # HEAT MAP Correlation Matrix
# ----> 2 corr = data.select_dtypes(include=np.number).corr()
#       3 plt.figure(figsize=(10,8))
#       4 sns.heatmap(corr, annot=True, cmap='coolwarm', center=0)
#
# NameError: name 'data' is not defined

# %% [markdown]
# ##### Target Variable Analysis

# %% [markdown]
# ##### Time-based Checks

# %% [markdown]
# ##### Data Integrity and Consistency

# %% [markdown]
# ##### Basic Feature Engineering

# %% [markdown]
# ##### Visualization Essentials

# %% [markdown]
# ##### Initial Insights and Hypothesis

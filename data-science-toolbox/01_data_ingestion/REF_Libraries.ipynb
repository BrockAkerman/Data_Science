# %% [markdown]
# # 📦 Reference Code for Library Imports

# %%
# ==============================================================================
# 📦 MODULE: CORE UTILITIES
# ==============================================================================
import os                          # OS-level file and directory path operations
import re                          # Regular expressions for string pattern matching
import logging                     # Tracks events and errors for production debugging
import warnings                    # Manages alert messages (e.g., suppressing deprecations)
from pathlib import Path           # Modern, object-oriented filesystem paths
from typing import Dict, Tuple, Any # Type hinting for cleaner, self-documenting code
from tqdm.auto import tqdm         # Interactive progress bars for loops and apply()
import gc                          # Garbage collection for managing large memory objects
import time                        # Timing execution blocks for performance profiling

# ==============================================================================
# 📊 MODULE: DATA WRANGLING
# ==============================================================================
import pandas as pd                # Primary tool for DataFrame manipulation and CSV/Excel I/O
import numpy as np                 # Vectorized numerical operations and array math
from datetime import datetime      # Parsing and manipulating time-series/date data

# ==============================================================================
# 🎨 MODULE: VISUALIZATION
# ==============================================================================
import matplotlib.pyplot as plt    # Low-level plotting engine for custom charts
import matplotlib.ticker as mtick  # Formatting axis labels (e.g., adding % or $ signs)
import matplotlib.gridspec as gridspec  # Complex sub-plot layouts (e.g., 2 small plots over 1 wide)
from matplotlib.colors import (
    LinearSegmentedColormap        # Creating custom color gradients for heatmaps
)
import seaborn as sns              # High-level statistical visualization (built on Matplotlib)

# ==============================================================================
# ⚙️ MODULE: PREPROCESSING & PIPELINES
# ==============================================================================
from sklearn.model_selection import (
    train_test_split,              # Splits data into training and testing subsets
    cross_val_score,               # Evaluates model performance via K-Fold validation
    RandomizedSearchCV,            # Efficiently finds optimal hyperparameters
    StratifiedKFold                # K-Fold split that preserves class balance in targets
)
from sklearn.preprocessing import (
    StandardScaler,                # Scales features to mean=0 and variance=1
    LabelEncoder                   # Converts categorical text into numerical integers
)
from sklearn.pipeline import Pipeline # Chains preprocessing and modeling into one object

# ==============================================================================
# 🤖 MODULE: MACHINE LEARNING MODELS
# ==============================================================================
from sklearn.linear_model import LogisticRegression           # Baseline linear classifier
from sklearn.tree import DecisionTreeClassifier               # Simple tree-based logic
from sklearn.ensemble import (
    RandomForestClassifier,        # Bagging-based ensemble of decision trees
    GradientBoostingClassifier     # Sequential boosting ensemble
)
import lightgbm as lgb             # Fast, histogram-based gradient boosting (Microsoft)
import xgboost as xgb              # High-performance extreme gradient boosting

# ==============================================================================
# 📈 MODULE: EVALUATION METRICS
# ==============================================================================
from sklearn.metrics import (
    accuracy_score,                # Overall % of correct predictions
    roc_auc_score,                 # Model's ability to distinguish between classes
    roc_curve,                     # Data for plotting TPR vs FPR
    confusion_matrix,              # Matrix of TP, TN, FP, FN counts
    ConfusionMatrixDisplay,        # Visual wrapper for the confusion matrix
    classification_report,         # Summary of Precision, Recall, and F1-score
    brier_score_loss,              # Measures accuracy of predicted probabilities
    precision_recall_curve,        # Data for plotting precision vs recall trade-off
    average_precision_score        # Summarizes PR-curve into a single number
)
from sklearn.calibration import calibration_curve             # Checks if probabilities reflect reality
from sklearn.inspection import (
    permutation_importance,        # Measures feature impact by shuffling values
    PartialDependenceDisplay       # Visualizes relationship between feature and target
)

# ===============================
# Statistical Testing (A/B Testing)
# ===============================
import scipy.stats as stats        # Core stats: t-tests, chi-square, and p-values
from statsmodels.stats.proportion import (
    proportions_ztest,             # Z-test for comparing conversion rates
    proportion_confint             # Calculates confidence intervals for proportions
)
from statsmodels.stats.power import (
    NormalIndPower                 # Power analysis to determine required sample size
)

# ==============================================================================
# ⚖️ MODULE: IMBALANCED DATA & EXPLAINABILITY
# ==============================================================================
from imblearn.over_sampling import SMOTE # Synthetically creates minority class samples
from collections import Counter    # Quickly counts class distributions
import shap                        # Game-theory based model interpretation (feature impact)
import scipy.stats as stats        # Statistical distributions for hyperparameter tuning

# ==============================================================================
# 🛠️ GLOBAL SETTINGS & CONFIGURATION
# ==============================================================================
warnings.filterwarnings('ignore')        # Hides cluttering warning messages
pd.set_option('display.max_columns', None) # Ensures all columns are visible in .head() calls

# Consistent aesthetic for all charts
sns.set_theme(style='whitegrid', context='talk', palette='deep')

# Seed for reproducibility across the entire project
RANDOM_STATE = 42

print('✅ Modular library reference loaded.')
